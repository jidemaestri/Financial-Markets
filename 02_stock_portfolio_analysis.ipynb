# %% [markdown]
# <a href="https://colab.research.google.com/github/jidemaestri/Financial-Markets/blob/master/02_stock_portfolio_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

import yfinance as yf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.6 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
stocks = ["AAPL", "GOOG", "MSFT", "VALE", "MELI", "DIS", "KO", "MCD", "NVDA", "PAM", "GGAL", "BBAR"]

# %%
for stock in stocks:
    info = yf.Ticker(stock).info
    print(info["shortName"], info["regularMarketPrice"], info["sector"], info["country"])
# Out:
# Apple Inc. 142.91 Technology United States
# Alphabet Inc. 97.31 Communication Services United States
# Microsoft Corporation 245.12 Technology United States
# VALE S.A. 16.76 Basic Materials Brazil
# MercadoLibre, Inc. 863.09 Consumer Cyclical Uruguay
# Walt Disney Company (The) 92.29 Communication Services United States
# Coca-Cola Company (The) 63.44 Consumer Defensive United States
# McDonald's Corporation 271.77 Consumer Cyclical United States
# NVIDIA Corporation 159.87 Technology United States
# Pampa Energia S.A. Pampa Energi 27.04 Utilities Argentina
# Grupo Financiero Galicia S.A. 7.63 Financial Services Argentina
# Banco BBVA Argentina S.A. 2.88 Financial Services Argentina

# %%
# Importar matplotlib y utilizar el estilo "fivethirtyeight"
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
print(info)
# Out:
# {'zip': 'C1054AAA', 'sector': 'Financial Services', 'fullTimeEmployees': 5880, 'longBusinessSummary': 'Banco BBVA Argentina S.A. provides various banking products and services to individuals and companies in Argentina. It provides retail banking products and services, such as checking and savings accounts, time deposits, credit cards, consumer and secured loans, mortgages, insurance, and investment products to individuals; and small and medium-sized companies products and services, including financing products, factoring, checking accounts, time deposits, transactional and payroll services, insurance, and investment products to private-sector companies. The company also provides corporate and investment banking products and services, such as global transaction services; global markets solutions comprising risk management and securities brokerage; long-term financing products, including project finance and syndicated loans; and corporate finance services comprising mergers and acquisi
# ...

# %%
import pandas as pd
#from pandas import to_numeric
stock_portfolio = pd.DataFrame()

# %%
# # Definir una función que convierta los números a valores en millones
# def to_millions(x):
#     return "{:.2f}M".format(x / 1000000)

# %%
for stock in stocks:
    financials = yf.Ticker(stock).info

    name = financials["shortName"]
    current_price = financials["regularMarketPrice"]
    roa = financials["returnOnAssets"]
    fcf_margin = financials["freeCashflow"]
    gross_margin = financials["grossMargins"]
    current_ratio = financials["currentRatio"]
    free_cash_flow = financials["freeCashflow"]
    pb_ratio = financials["priceToBook"]
    revenue_growth = financials["revenueGrowth"] 
    earningsGrowth = financials["earningsGrowth"]
    targetLowPrice = financials["targetLowPrice"]
    targetMedianPrice = financials["targetMedianPrice"]
    targetHighPrice = financials["targetHighPrice"]
    net_profit_margin = financials["netIncomeToCommon"] / financials["totalRevenue"]
    #evfcf_ratio = financials["enterpriseValue"]/financials["freeCashflow"]
    debt_to_equity = financials["debtToEquity"]
    priceToSalesTrailing12Months = financials["priceToSalesTrailing12Months"]
    twoHundredDayAverage  = financials["twoHundredDayAverage"]
    totalCashPerShare = financials["totalCashPerShare"]

    
    
    stock_portfolio = stock_portfolio.append({"Stock": name, 
                    "Current Price": current_price,
                    "Debt/Equity": debt_to_equity, 
                    "Current Ratio": current_ratio, 
                    "Price To Sales 12M Ratio": priceToSalesTrailing12Months, 
                    #"EV/FCF Ratio": evfcf_ratio, 
                    "P/B Ratio": pb_ratio, 
                    "Revenue Growth": revenue_growth, 
                    "ROA": roa, 
                    "target High Price": targetHighPrice,
                    "target Median Price": targetMedianPrice,
                    "target Low Price": targetLowPrice,
                    "Gross Margin": gross_margin, 
                    "Free Cash Flow": free_cash_flow,
                    "FCF Margin": fcf_margin, 
                    "Net Profit Margin": net_profit_margin,
                    "total Cash Per Share": totalCashPerShare, 
                    "twoHundred Day Avg": twoHundredDayAverage,
                    },
                   ignore_index=True)

# %%
stock_portfolio
# Out:
#                               Stock  Current Price Debt/Equity Current Ratio  \
# 0                        Apple Inc.          0.00M       0.00M         0.00M
# 1                     Alphabet Inc.          0.00M       0.00M         0.00M
# 2             Microsoft Corporation          0.00M       0.00M         0.00M
# 3                         VALE S.A.          0.00M       0.00M         0.00M
# 4                MercadoLibre, Inc.          0.00M       0.00M         0.00M
# 5         Walt Disney Company (The)          0.00M       0.00M         0.00M
# 6           Coca-Cola Company (The)          0.00M       0.00M         0.00M
# 7            McDonald's Corporation          0.00M        None         0.00M
# 8                NVIDIA Corporation          0.00M       0.00M         0.00M
# 9   Pampa Energia S.A. Pampa Energi          0.00M       0.00M         0.00M
# 10    Grupo Financiero Galicia S.A.          0.00M        None          None
# ...

# %%
stock_portfolio.columns
# Out:
# Index(['Stock', 'Current Price', 'Debt/Equity', 'Current Ratio',
#        'Price To Sales 12M Ratio', 'EV/FCF Ratio', 'P/B Ratio',
#        'Revenue Growth', 'ROA', 'target High Price', 'target Median Price',
#        'target Low Price', 'Gross Margin', 'Free Cash Flow', 'FCF Margin',
#        'Net Profit Margin'],
#       dtype='object')

# %% [markdown]
# #### Backlog API - Keys YFINANCE API

# %%
stock = "AAPL"
info = yf.Ticker(stock).info

for key in info.keys():
    print(key)
# Out:
# zip
# sector
# fullTimeEmployees
# longBusinessSummary
# city
# phone
# state
# country
# companyOfficers
# website
# maxAge
# address1
# industry
# ebitdaMargins
# profitMargins
# grossMargins
# operatingCashflow
# revenueGrowth
# operatingMargins
# ebitda
# targetLowPrice
# recommendationKey
# grossProfits
# freeCashflow
# targetMedianPrice
# currentPrice
# earningsGrowth
# currentRatio
# returnOnAssets
# numberOfAnalystOpinions
# targetMeanPrice
# debtToEquity
# returnOnEquity
# targetHighPrice
# totalCash
# totalDebt
# totalRevenue
# totalCashPerShare
# financialCurrency
# revenuePerShare
# quickRatio
# recommendationMean
# exchange
# shortName
# longName
# exchangeTimezoneName
# exchangeTimezoneShortName
# isEsgPopulated
# gmtOffSetMilliseconds
# quoteType
# symbol
# messageBoardId
# market
# annualHoldingsTurnover
# enterpriseToRevenue
# beta3Year
# enterpriseToEbitda
# 52WeekChange
# morningStarRiskRating
# forwardEps
# revenueQuarterlyGrowth
# sharesOutstanding
# ...
